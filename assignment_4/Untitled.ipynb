# %%
from Lane_Test import Lane
import cv2

# %%
filename = 'test.jpg' 
original_frame = cv2.imread(filename)
lane_obj = Lane(orig_frame=original_frame)
lane_line_markings = lane_obj.get_line_markings()

# Plot the region of interest on the image
lane_obj.plot_roi(plot=True)

# %%
warped_frame = lane_obj.perspective_transform(plot=True)

# %%
histogram = lane_obj.calculate_histogram(plot=True)

# %%
 left_fit, right_fit = lane_obj.get_lane_line_indices_sliding_windows(
    plot=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11632/2219402610.py in <module>
# ----> 1 left_fit, right_fit = lane_obj.get_lane_line_indices_sliding_windows(
#       2    plot=False)
#
# D:\study\skill-lync\openCV\assignment_4\Lane_Test.py in get_lane_line_indices_sliding_windows(self, plot)
#     322
#     323     # Set the height of the sliding windows
# --> 324     window_height = np.int_(self.warped_frame.shape[0]/self.no_of_windows)
#     325
#     326     # Find the x and y coordinates of all the nonzero
#
# d:\programfiles\python39\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     303
#     304         if attr in __former_attrs__:
# --> 305             raise AttributeError(__former_attrs__[attr])
#     306
#     307         # Importing Tester requires importing all of UnitTest which is not a
#
# AttributeError: module 'numpy' has no attribute 'int'.
# `np.int` was a deprecated alias for the builtin `int`. To avoid this error in existing code, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
